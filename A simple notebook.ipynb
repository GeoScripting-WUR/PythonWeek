# %% [markdown]
# # Simple Notebook

# %% [markdown]
# This is some **markdown** text with $Latex$

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0, 10)
y =sin(x)
plot(x, y)
